# %% [markdown]
# # Imports

# %%
import pandas as pd

# %%
#!pip install fastparquet
# Out:
# ...
#   Using cached fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 314.8 kB/s  0:00:05 eta 0:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 4.5 MB/s  0:00:00 eta 0:00:01
# Using cached fsspec-2025.7.0-py3-none-any.whl (199 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [fastparquet] [fastparquet]
# ...

# %%
df_moves = pd.read_parquet("raw_data/df_moves.parquet")
df_game_info = pd.read_parquet("raw_data/df_game_info.parquet")

# %%
df_moves.head()
# Out:
#     game_id  ply  move_number color move_san move_uci  \
# 0  xiYGkO9x    1            1     w       e4     e2e4
# 1  xiYGkO9x    2            1     b       e6     e7e6
# 2  xiYGkO9x    3            2     w       d4     d2d4
# 3  xiYGkO9x    4            2     b       d5     d7d5
# 4  xiYGkO9x    5            3     w     exd5     e4d5
#
#                        comment nags  clock_s  emt_s  time_spent_s  eval  \
# 0  [%eval 0.18] [%clk 0:01:00]          60.0    NaN           NaN  18.0
# 1  [%eval 0.28] [%clk 0:01:00]          60.0    NaN           NaN  28.0
# 2  [%eval 0.28] [%clk 0:00:59]          59.0    NaN           1.0  28.0
# 3  [%eval 0.29] [%clk 0:01:00]          60.0    NaN           0.0  29.0
# 4  [%eval 0.22] [%clk 0:00:58]          58.0    NaN           1.0  22.0
#
#                                           fen_before
# 0  rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w ...
# 1  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
# ...

# %%
df_moves_cleaned = df_moves.drop(columns=["color","comment","fen_before","nags","emt_s"])

# %%
df_moves_cleaned.head()
# Out:
#     game_id  ply  move_number move_san move_uci  clock_s  time_spent_s  eval
# 0  xiYGkO9x    1            1       e4     e2e4     60.0           NaN  18.0
# 1  xiYGkO9x    2            1       e6     e7e6     60.0           NaN  28.0
# 2  xiYGkO9x    3            2       d4     d2d4     59.0           1.0  28.0
# 3  xiYGkO9x    4            2       d5     d7d5     60.0           0.0  29.0
# 4  xiYGkO9x    5            3     exd5     e4d5     58.0           1.0  22.0

# %%
df_moves_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 654784 entries, 0 to 654783
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   game_id       654784 non-null  object
#  1   ply           654784 non-null  int64
#  2   move_number   654784 non-null  int64
#  3   move_san      654784 non-null  object
#  4   move_uci      654784 non-null  object
#  5   clock_s       653587 non-null  float64
#  6   time_spent_s  633633 non-null  float64
#  7   eval          651783 non-null  float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 40.0+ MB

# %%
df_game_info.head()
# Out:
#     game_id                                           Event  \
# 0  xiYGkO9x                               Rated Bullet game
# 1  xfmq5EEK                               Rated Bullet game
# 2  PYRsQ91T                               Rated Bullet game
# 3  IrsW3N08  Blitz swiss https://lichess.org/swiss/MKBqe0rs
# 4  IybleZW8                                Rated Blitz game
#
#                            Site        Date Round      White        Black  \
# 0  https://lichess.org/xiYGkO9x  2025.07.01     -  Giakomo22       xan9xx
# 1  https://lichess.org/xfmq5EEK  2025.07.01     -   luis8730   Pablooo456
# 2  https://lichess.org/PYRsQ91T  2025.07.01     -  candelier   EwanMellor
# 3  https://lichess.org/IrsW3N08  2025.07.01     -     Kuphel  chesshuman1
# 4  https://lichess.org/IybleZW8  2025.07.01     -     Tito69  Elponycraak
#
#   Result     UTCDate   UTCTime  ...  BlackRatingDiff  ECO  \
# 0    1-0  2025.07.01  00:00:31  ...               -6  C01
# ...

# %%
df_game_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   game_id          10000 non-null  object
#  1   Event            10000 non-null  object
#  2   Site             10000 non-null  object
#  3   Date             10000 non-null  object
#  4   Round            10000 non-null  object
#  5   White            10000 non-null  object
#  6   Black            10000 non-null  object
#  7   Result           10000 non-null  object
#  8   UTCDate          10000 non-null  object
#  9   UTCTime          10000 non-null  object
#  10  WhiteElo         10000 non-null  object
#  11  BlackElo         10000 non-null  object
#  12  WhiteRatingDiff  10000 non-null  object
#  13  BlackRatingDiff  10000 non-null  object
#  14  ECO              10000 non-null  object
#  15  Opening          10000 non-null  object
# ...

# %%
df_game_info["WhiteElo"] = pd.to_numeric(df_game_info["WhiteElo"])
df_game_info["BlackElo"] = pd.to_numeric(df_game_info["BlackElo"])
